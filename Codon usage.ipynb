# %%
from Bio import SeqIO
from Bio.Seq import Seq
import pandas as pd
from os import walk
import os
mypath = os.path.abspath(os.getcwd()) + "/filtered_genomes"

files = []
for (dirpath, dirnames, filenames) in walk(mypath):
    files.extend(filenames)
    break

ext = "embl"

FileNames = []
IntergenomicGC = []
AAA = []
ACA = []
AGA = []
TTA = []
TCA = []
CAA = []
CTA = []
CCA = []
CGA = []
GAA = []
GTA = []
GCA = []
GGA = []
AAT = []
ACT = []
AGT = []
TAT = []
TTT = []
TCT = []
TGT = []
CAT = []
CTT = []
CCT = []
CGT = []
GAT = []
GTT = []
GCT = []
GGT = []
AAC = []
ACC = []
AGC = [] 
TAC = []
TTC = []
TCC = []
TGC = []
CAC = []
CTC = []
CCC = []
CGC = []
GAC = []
GTC = []
GCC = []
GGC = []
AAG = []
ACG = []
AGG = []
TTG = []
TCG = []
CAG = []
CTG = []
CCG = []
CGG = []
GAG = []
GTG = []
GCG = []
GGG = []


files_tot = len(files)
for index, name in enumerate(files):
    print("\n")
    print(f"Analyzing file {index+1} of {files_tot}: {name}")
    print("\n")
    record = SeqIO.read(f'filtered_genomes/{name}', ext)
    sequence = record.seq
    FileNames.append(str(name))
    
    start = 0
    coding_sequences = []
    intergenomic_sequence = []  # It will contain the sequences out of the locations bounds
    intergenomic_sequence_list = []  # It will contain the locations bounds
    intergenomic_sequence_string = ""  # intergenomic sequence
    
    for feature in record.features:

        locations= feature.location
        s = int(locations.nofuzzy_start)
        e = int(locations.nofuzzy_end)
        st = int(locations.strand)
        
        gene_start = int(locations.nofuzzy_start)

        if gene_start > start:
            ig_sequence = sequence[start:gene_start]
            intergenomic_sequence.append(str(ig_sequence))
            intergenomic_sequence_list.append((start, gene_start))

        new_start = int(locations.nofuzzy_end)

        if new_start != len(sequence):
            start = new_start

        #Reversing complementary strands
        if st == -1:
            sequence_negativestrand = str(sequence[s:e])
            sequence_negativestrand= sequence_negativestrand[::-1]
            sequence_negativestrand= sequence_negativestrand.replace("A","b")
            sequence_negativestrand= sequence_negativestrand.replace("T","A")
            sequence_negativestrand= sequence_negativestrand.replace("b","T")
            sequence_negativestrand= sequence_negativestrand.replace("C","d")
            sequence_negativestrand= sequence_negativestrand.replace("G","C")
            sequence_negativestrand= sequence_negativestrand.replace("d","G")

        #Discarding the pseudogenes

            ok = 0
            genes = str(sequence_negativestrand)


            if len(genes)%3 != 0:
                ok= 1
            elif genes[:3] != "ATG" and genes[:3] != "GTG" and genes[:3] != "TTG":
                ok= 2
            elif genes[-3:] != "TAA" and genes[-3:] != "TAG" and genes[-3:] != "TGA":
                ok= 3


            if st == -1 and ok == 0:
                coding_sequences.append(genes)
        
        ok = 0
        genes = str(sequence[s:e])
    
        if len(genes)%3 != 0:
            ok= 1
        elif genes[:3] != "ATG" and genes[:3] != "GTG" and genes[:3] != "TTG":
            ok= 2
        elif genes[-3:] != "TAA" and genes[-3:] != "TAG" and genes[-3:] != "TGA":
            ok= 3
        elif len(genes) == len(sequence):
            ok= 4

        if st == 1 and ok == 0:
            coding_sequences.append(genes)

        #checking for errors
        check = False
        if check and st == 1 and ok != 0:
            print(locations)
            print(ok)
            print(genes[:3])
            print(genes[-3:])
            
    if start != len(sequence):
        ig_sequence = sequence[start:len(sequence)]
        intergenomic_sequence.append(str(ig_sequence))
        intergenomic_sequence_list.append((start, gene_start))

    intergenomic_sequence_string = "".join(intergenomic_sequence)

    # Intergenomic GC content
    IgGC = intergenomic_sequence_string.count("G") + intergenomic_sequence_string.count("C")
    IgGC_content = (IgGC / len(intergenomic_sequence_string)) * 100
    print(f"Intergenomic GC content: {IgGC_content:.2f}%")
    IntergenomicGC.append(IgGC_content)
    
    coding_sequencewhole = "".join(coding_sequences)
    aminoacids_sequence = Seq(coding_sequencewhole).translate()
    
    
    #Codon counting 
    AAAcount = 0
    AATcount = 0
    AACcount = 0
    AAGcount = 0
    ACAcount = 0
    ACCcount = 0
    ACGcount = 0
    ACTcount = 0
    AGAcount = 0
    AGTcount = 0
    AGCcount = 0
    AGGcount = 0
    TATcount = 0
    TACcount = 0
    TTAcount = 0
    TTTcount = 0
    TTCcount = 0
    TTGcount = 0
    TCAcount = 0
    TCCcount = 0
    TCGcount = 0
    TCTcount = 0
    TGTcount = 0
    TGCcount = 0
    CAAcount = 0  
    CATcount = 0
    CACcount = 0
    CAGcount = 0
    CTAcount = 0
    CTCcount = 0
    CTGcount = 0
    CTTcount = 0
    CCAcount = 0
    CCCcount = 0
    CCGcount = 0
    CCTcount = 0
    CGAcount = 0
    CGCcount = 0
    CGGcount = 0
    CGTcount = 0
    GAAcount = 0
    GATcount = 0
    GACcount = 0
    GAGcount = 0
    GTAcount = 0
    GTCcount = 0
    GTGcount = 0
    GTTcount = 0
    GCAcount = 0
    GCCcount = 0
    GCGcount = 0
    GCTcount = 0
    GGTcount = 0
    GGCcount = 0
    GGAcount = 0
    GGGcount = 0
    
    for cds in coding_sequences:
        for i in range(0, len(cds), 3):
            codons = cds[i: i + 3]
            AAA1 = codons.count("AAA")
            AAAcount += AAA1
            AAT1 = codons.count("AAT")
            AATcount += AAT1
            AAC1 = codons.count("AAC")
            AACcount += AAC1
            AAG1 = codons.count("AAG")
            AAGcount += AAG1
            ACA1 = codons.count("ACA")
            ACAcount += ACA1
            ACC1 = codons.count("ACC")
            ACCcount += ACC1
            ACG1 = codons.count("ACG")
            ACGcount += ACG1
            ACT1 = codons.count("ACT")
            ACTcount += ACT1
            AGA1 = codons.count("AGA")
            AGAcount += AGA1
            AGT1 = codons.count("AGT")
            AGTcount += AGT1
            AGC1 = codons.count("AGC")
            AGCcount += AGC1
            AGG1 = codons.count("AGG")
            AGGcount += AGG1
            CAA1 = codons.count("CAA")
            CAAcount += CAA1
            CAT1 = codons.count("CAT")
            CATcount += CAT1
            CAC1 = codons.count("CAC")
            CACcount += CAC1
            CAG1 = codons.count("CAG")
            CAGcount += CAG1
            CCA1 = codons.count("CCA")
            CCAcount += CCA1
            CCC1 = codons.count("CCC")
            CCCcount += CCC1
            CCG1 = codons.count("CCG")
            CCGcount += CCG1
            CCT1 = codons.count("CCT")
            CCTcount += CCT1
            CTA1 = codons.count("CTA")
            CTAcount += CTA1
            CTC1 = codons.count("CTC")
            CTCcount += CTC1
            CTG1 = codons.count("CTG")
            CTGcount += CTG1
            CTT1 = codons.count("CTT")
            CTTcount += CTT1
            CGA1 = codons.count("CGA")
            CGAcount += CGA1
            CGC1 = codons.count("CGC")
            CGCcount += CGC1
            CGG1 = codons.count("CGG")
            CGGcount += CGG1
            CGT1 = codons.count("CGT")
            CGTcount += CGT1
            TAT1 = codons.count("TAT")
            TATcount += TAT1
            TAC1 = codons.count("TAC")
            TACcount += TAC1
            TCA1 = codons.count("TCA")
            TCAcount += TCA1
            TCC1 = codons.count("TCC")
            TCCcount += TCC1
            TCG1 = codons.count("TCG")
            TCGcount += TCG1
            TCT1 = codons.count("TCT")
            TCTcount += TCT1
            TTA1 = codons.count("TTA")
            TTAcount += TTA1
            TTT1 = codons.count("TTT")
            TTTcount += TTT1
            TTC1 = codons.count("TTC")
            TTCcount += TTC1
            TTG1 = codons.count("TTG")
            TTGcount += TTG1
            TGT1 = codons.count("TGT")
            TGTcount += TGT1
            TGC1 = codons.count("TGC")
            TGCcount += TGC1
            GAA1 = codons.count("GAA")
            GAAcount += GAA1
            GAT1 = codons.count("GAT")
            GATcount += GAT1
            GAC1 = codons.count("GAC")
            GACcount += GAC1
            GAG1 = codons.count("GAG")
            GAGcount += GAG1
            GTA1 = codons.count("GTA")
            GTAcount += GTA1
            GTC1 = codons.count("GTC")
            GTCcount += GTC1
            GTG1 = codons.count("GTG")
            GTGcount += GTG1
            GTT1 = codons.count("GTT")
            GTTcount += GTT1
            GCA1 = codons.count("GCA")
            GCAcount += GCA1
            GCC1 = codons.count("GCC")
            GCCcount += GCC1
            GCG1 = codons.count("GCG")
            GCGcount += GCG1
            GCT1 = codons.count("GCT")
            GCTcount += GCT1
            GGA1 = codons.count("GGA")
            GGAcount += GGA1
            GGC1 = codons.count("GGC")
            GGCcount += GGC1
            GGG1 = codons.count("GGG")
            GGGcount += GGG1
            GGT1 = codons.count("GGT")
            GGTcount += GGT1
            
    
    
    AAA.append(AAAcount/ (AAAcount+AAGcount)*100)
    AAT.append(AATcount/ (AATcount+AACcount)*100)
    AAC.append(AACcount/ (AATcount+AACcount)*100)
    AAG.append(AAGcount/ (AAAcount+AAGcount)*100)
    ACA.append(ACAcount/ (ACAcount+ACTcount+ACCcount+ACGcount)*100)
    ACC.append(ACCcount/ (ACAcount+ACTcount+ACCcount+ACGcount)*100)
    ACG.append(ACGcount/ (ACAcount+ACTcount+ACCcount+ACGcount)*100)
    ACT.append(ACTcount/ (ACAcount+ACTcount+ACCcount+ACGcount)*100)
    AGA.append(AGAcount/ (AGAcount+AGGcount)*100)
    AGT.append(AGTcount/ (AGTcount+AGCcount)*100)
    AGC.append(AGCcount/ (AGTcount+AGCcount)*100)
    AGG.append(AGGcount/ (AGAcount+AGGcount)*100)
    TAT.append(TATcount/ (TATcount+TACcount)*100)
    TAC.append(TACcount/ (TATcount+TACcount)*100)
    TTA.append(TTAcount/ (TTAcount+TTGcount)*100)
    TTT.append(TTTcount/ (TTTcount+TTCcount)*100)
    TTC.append(TTCcount/ (TTTcount+TTCcount)*100)
    TTG.append(TTGcount/ (TTAcount+TTGcount)*100)
    TCA.append(TCAcount/ (TCAcount+TCTcount+TCGcount+TCCcount)*100)
    TCC.append(TCCcount/ (TCAcount+TCTcount+TCGcount+TCCcount)*100)
    TCG.append(TCGcount/ (TCAcount+TCTcount+TCGcount+TCCcount)*100)
    TCT.append(TCTcount/ (TCAcount+TCTcount+TCGcount+TCCcount)*100)
    TGT.append(TGTcount/ (TGTcount+TGCcount)*100)
    TGC.append(TGCcount/ (TGTcount+TGCcount)*100)
    CAA.append(CAAcount/ (CAAcount+CAGcount)*100)
    CAT.append(CATcount/ (CACcount+CATcount)*100)
    CAC.append(CACcount/ (CACcount+CATcount)*100)
    CAG.append(CAGcount/ (CAAcount+CAGcount)*100)
    CTA.append(CTAcount/ (CTAcount+CTCcount+CTCcount+CTTcount)*100)
    CTC.append(CTCcount/ (CTAcount+CTCcount+CTCcount+CTTcount)*100)
    CTG.append(CTGcount/ (CTAcount+CTCcount+CTCcount+CTTcount)*100)
    CTT.append(CTTcount/ (CTAcount+CTCcount+CTCcount+CTTcount)*100)
    CCA.append(CCAcount/ (CCAcount+CCTcount+CCCcount+CCGcount)*100)
    CCC.append(CCCcount/ (CCAcount+CCTcount+CCCcount+CCGcount)*100)
    CCG.append(CCGcount/ (CCAcount+CCTcount+CCCcount+CCGcount)*100)
    CCT.append(CCTcount/ (CCAcount+CCTcount+CCCcount+CCGcount)*100)
    CGA.append(CGAcount/ (CGAcount+CGTcount+CGCcount+CGGcount)*100)
    CGC.append(CGCcount/ (CGAcount+CGTcount+CGCcount+CGGcount)*100)
    CGG.append(CGGcount/ (CGAcount+CGTcount+CGCcount+CGGcount)*100)
    CGT.append(CGTcount/ (CGAcount+CGTcount+CGCcount+CGGcount)*100)
    GAA.append(GAAcount/ (GAAcount+GAGcount)*100)
    GAT.append(GATcount/ (GACcount+GATcount)*100)
    GAC.append(GACcount/ (GACcount+GATcount)*100)
    GAG.append(GAGcount/ (GAAcount+GAGcount)*100)
    GTA.append(GTAcount/ (GTAcount+GTTcount+GTCcount+GTGcount)*100)
    GTC.append(GTCcount/ (GTAcount+GTTcount+GTCcount+GTGcount)*100)
    GTG.append(GTGcount/ (GTAcount+GTTcount+GTCcount+GTGcount)*100)
    GTT.append(GTTcount/ (GTAcount+GTTcount+GTCcount+GTGcount)*100)
    GCA.append(GCAcount/ (GCAcount+GCTcount+GCCcount+GCGcount)*100)
    GCC.append(GCCcount/ (GCAcount+GCTcount+GCCcount+GCGcount)*100)
    GCG.append(GCGcount/ (GCAcount+GCTcount+GCCcount+GCGcount)*100)
    GCT.append(GCTcount/ (GCAcount+GCTcount+GCCcount+GCGcount)*100)
    GGT.append(GGTcount/ (GGAcount+GGTcount+GGCcount+GGGcount)*100)
    GGA.append(GGAcount/ (GGAcount+GGTcount+GGCcount+GGGcount)*100)
    GGG.append(GGGcount/ (GGAcount+GGTcount+GGCcount+GGGcount)*100)
    GGC.append(GGCcount/ (GGAcount+GGTcount+GGCcount+GGGcount)*100)
# Out:
# Analyzing file 1 of 100: CP002479.embl
#
#
# Intergenomic GC content: 55.94%
#
#
# Analyzing file 2 of 100: CP002512.embl
#
#
# Intergenomic GC content: 34.16%
#
#
# Analyzing file 3 of 100: CP002514.embl
#
#
# Intergenomic GC content: 56.99%
#
#
# Analyzing file 4 of 100: CP002521.embl
#
#
# Intergenomic GC content: 66.15%
#
#
# Analyzing file 5 of 100: CP002528.embl
#
#
# Intergenomic GC content: 33.06%
#
#
# Analyzing file 6 of 100: CP002542.embl
#
#
# Intergenomic GC content: 35.43%
#
#
# Analyzing file 7 of 100: CP002543.embl
#
#
# Intergenomic GC content: 33.02%
#
#
# Analyzing file 8 of 100: CP002544.embl
#
#
# Intergenomic GC content: 40.21%
#
#
# Analyzing file 9 of 100: CP002546.embl
#
#
# Intergenomic GC content: 55.44%
#
#
# Analyzing file 10 of 100: CP002547.embl
#
#
# Intergenomic GC content: 42.30%
#
#
# Analyzing file 11 of 100: CP002548.embl
#
#
# Intergenomic GC content: 21.82%
#
#
# Analyzing file 12 of 100: CP002568.embl
#
#
# Intergenomic GC content: 63.36%
#
#
# Analyzing file 13 of 100: CP002584.embl
#
#
# Intergenomic GC content: 36.91%
#
#
# Analyzing file 14 of 100: CP002593.embl
#
#
# Intergenomic GC content: 72.65%
#
#
# Analyzing file 15 of 100: CP002606.embl
#
#
# Intergenomic GC content: 35.52%
#
#
# Analyzing file 16 of 100: CP002623.embl
#
#
# Intergenomic GC content: 52.01%
#
#
# Analyzing file 17 of 100: CP002628.embl
#
#
# Intergenomic GC content: 56.12%
#
#
# Analyzing file 18 of 100: CP002629.embl
#
#
# Intergenomic GC content: 44.56%
#
#
# Analyzing file 19 of 100: CP002630.embl
#
#
# Intergenomic GC content: 61.71%
#
#
# Analyzing file 20 of 100: CP002638.embl
#
#
# Intergenomic GC content: 67.62%
#
#
# Analyzing file 21 of 100: CP002657.embl
#
#
# Intergenomic GC content: 64.09%
#
#
# Analyzing file 22 of 100: CP002663.embl
#
#
# Intergenomic GC content: 49.46%
#
#
# Analyzing file 23 of 100: CP002666.embl
#
#
# Intergenomic GC content: 75.36%
#
#
# Analyzing file 24 of 100: CP002667.embl
#
#
# Intergenomic GC content: 31.67%
#
#
# Analyzing file 25 of 100: CP002683.embl
#
#
# Intergenomic GC content: 39.97%
#
#
# Analyzing file 26 of 100: CP002690.embl
#
#
# Intergenomic GC content: 30.60%
#
#
# Analyzing file 27 of 100: CP002691.embl
#
#
# Intergenomic GC content: 45.75%
#
#
# Analyzing file 28 of 100: CP002701.embl
#
#
# Intergenomic GC content: 14.74%
#
#
# Analyzing file 29 of 100: CP002725.embl
#
#
# Intergenomic GC content: 34.82%
#
#
# Analyzing file 30 of 100: CP002738.embl
#
#
# Intergenomic GC content: 46.95%
#
#
# Analyzing file 31 of 100: CP002786.embl
#
#
# Intergenomic GC content: 59.09%
#
#
# Analyzing file 32 of 100: CP002810.embl
#
#
# Intergenomic GC content: 72.57%
#
#
# Analyzing file 33 of 100: CP002825.embl
#
#
# Intergenomic GC content: 26.95%
#
#
# Analyzing file 34 of 100: CP002831.embl
#
#
# Intergenomic GC content: 45.68%
#
#
# Analyzing file 35 of 100: CP002835.embl
#
#
# Intergenomic GC content: 38.51%
#
#
# Analyzing file 36 of 100: CP002858.embl
#
#
# Intergenomic GC content: 35.63%
#
#
# Analyzing file 37 of 100: CP002859.embl
#
#
# Intergenomic GC content: 44.47%
#
#
# Analyzing file 38 of 100: CP002874.embl
#
#
# Intergenomic GC content: 20.55%
#
#
# Analyzing file 39 of 100: CP002876.embl
#
#
# Intergenomic GC content: 39.43%
#
#
# Analyzing file 40 of 100: CP002899.embl
#
#
# Intergenomic GC content: 26.57%
#
#
# Analyzing file 41 of 100: CP002901.embl
#
#
# Intergenomic GC content: 52.82%
#
#
# Analyzing file 42 of 100: CP002902.embl
#
#
# Intergenomic GC content: 56.37%
#
#
# Analyzing file 43 of 100: CP002930.embl
#
#
# Intergenomic GC content: 44.78%
#
#
# Analyzing file 44 of 100: CP002955.embl
#
#
# Intergenomic GC content: 36.04%
#
#
# Analyzing file 45 of 100: CP002959.embl
#
#
# Intergenomic GC content: 53.19%
#
#
# Analyzing file 46 of 100: CP002961.embl
#
#
# Intergenomic GC content: 33.30%
#
#
# Analyzing file 47 of 100: CP002976.embl
#
#
# Intergenomic GC content: 56.03%
#
#
# Analyzing file 48 of 100: CP002985.embl
#
#
# Intergenomic GC content: 51.89%
#
#
# Analyzing file 49 of 100: CP002987.embl
#
#
# Intergenomic GC content: 32.55%
#
#
# Analyzing file 50 of 100: CP002991.embl
#
#
# Intergenomic GC content: 31.79%
#
#
# Analyzing file 51 of 100: CP002999.embl
#
#
# Intergenomic GC content: 39.47%
#
#
# Analyzing file 52 of 100: CP003051.embl
#
#
# Intergenomic GC content: 63.74%
#
#
# Analyzing file 53 of 100: CP003058.embl
#
#
# Intergenomic GC content: 43.18%
#
#
# Analyzing file 54 of 100: CP003075.embl
#
#
# Intergenomic GC content: 57.04%
#
#
# Analyzing file 55 of 100: CP003096.embl
#
#
# Intergenomic GC content: 44.46%
#
#
# Analyzing file 56 of 100: CP003108.embl
#
#
# Intergenomic GC content: 39.35%
#
#
# Analyzing file 57 of 100: CP003119.embl
#
#
# Intergenomic GC content: 64.17%
#
#
# Analyzing file 58 of 100: CP003130.embl
#
#
# Intergenomic GC content: 54.63%
#
#
# Analyzing file 59 of 100: CP003147.embl
#
#
# Intergenomic GC content: 45.98%
#
#
# Analyzing file 60 of 100: CP003153.embl
#
#
# Intergenomic GC content: 63.25%
#
#
# Analyzing file 61 of 100: CP003154.embl
#
#
# Intergenomic GC content: 60.63%
#
#
# Analyzing file 62 of 100: CP003155.embl
#
#
# Intergenomic GC content: 42.84%
#
#
# Analyzing file 63 of 100: CP003156.embl
#
#
# Intergenomic GC content: 38.70%
#
#
# Analyzing file 64 of 100: CP003171.embl
#
#
# Intergenomic GC content: 50.84%
#
#
# Analyzing file 65 of 100: CP003178.embl
#
#
# Intergenomic GC content: 42.59%
#
#
# Analyzing file 66 of 100: CP003183.embl
#
#
# Intergenomic GC content: 52.25%
#
#
# Analyzing file 67 of 100: CP003191.embl
#
#
# Intergenomic GC content: 38.32%
#
#
# Analyzing file 68 of 100: CP003198.embl
#
#
# Intergenomic GC content: 43.75%
#
#
# Analyzing file 69 of 100: CP003203.embl
#
#
# Intergenomic GC content: 58.35%
#
#
# Analyzing file 70 of 100: CP003236.embl
#
#
# Intergenomic GC content: 64.99%
#
#
# Analyzing file 71 of 100: CP003255.embl
#
#
# Intergenomic GC content: 56.40%
#
#
# Analyzing file 72 of 100: CP003257.embl
#
#
# Intergenomic GC content: 28.03%
#
#
# Analyzing file 73 of 100: CP003260.embl
#
#
# Intergenomic GC content: 37.36%
#
#
# Analyzing file 74 of 100: CP003264.embl
#
#
# Intergenomic GC content: 35.68%
#
#
# Analyzing file 75 of 100: CP003273.embl
#
#
# Intergenomic GC content: 39.96%
#
#
# Analyzing file 76 of 100: CP003280.embl
#
#
# Intergenomic GC content: 33.98%
#
#
# Analyzing file 77 of 100: CP003281.embl
#
#
# Intergenomic GC content: 34.12%
#
#
# Analyzing file 78 of 100: CP003283.embl
#
#
# Intergenomic GC content: 33.94%
#
#
# Analyzing file 79 of 100: CP003313.embl
#
#
# Intergenomic GC content: 32.97%
#
#
# Analyzing file 80 of 100: CP003315.embl
#
#
# Intergenomic GC content: 12.42%
#
#
# Analyzing file 81 of 100: CP003345.embl
#
#
# Intergenomic GC content: 27.84%
#
#
# Analyzing file 82 of 100: CP003346.embl
#
#
# Intergenomic GC content: 42.67%
#
#
# Analyzing file 83 of 100: CP003349.embl
#
#
# Intergenomic GC content: 35.49%
#
#
# Analyzing file 84 of 100: CP003350.embl
#
#
# Intergenomic GC content: 62.74%
#
#
# Analyzing file 85 of 100: CP003359.embl
#
#
# Intergenomic GC content: 30.40%
#
#
# Analyzing file 86 of 100: CP003360.embl
#
#
# Intergenomic GC content: 48.12%
#
#
# Analyzing file 87 of 100: CP003364.embl
#
#
# Intergenomic GC content: 60.24%
#
#
# Analyzing file 88 of 100: CP003379.embl
#
#
# Intergenomic GC content: 58.96%
#
#
# Analyzing file 89 of 100: CP003382.embl
#
#
# Intergenomic GC content: 61.75%
#
#
# Analyzing file 90 of 100: CP003389.embl
#
#
# Intergenomic GC content: 67.09%
#
#
# Analyzing file 91 of 100: CP003390.embl
#
#
# Intergenomic GC content: 42.29%
#
#
# Analyzing file 92 of 100: CP003403.embl
#
#
# Intergenomic GC content: 43.47%
#
#
# Analyzing file 93 of 100: CP003415.embl
#
#
# Intergenomic GC content: 42.24%
#
#
# Analyzing file 94 of 100: CP003418.embl
#
#
# Intergenomic GC content: 28.56%
#
#
# Analyzing file 95 of 100: CP003422.embl
#
#
# Intergenomic GC content: 52.20%
#
#
# Analyzing file 96 of 100: CP003466.embl
#
#
# Intergenomic GC content: 55.85%
#
#
# Analyzing file 97 of 100: CP003470.embl
#
#
# Intergenomic GC content: 66.88%
#
#
# Analyzing file 98 of 100: CP003488.embl
#
#
# Intergenomic GC content: 33.83%
#
#
# Analyzing file 99 of 100: CP003493.embl
#
#
# Intergenomic GC content: 65.93%
#
#
# Analyzing file 100 of 100: CP003495.embl
#
#
# Intergenomic GC content: 67.02%

# %%
df = pd.DataFrame(
    data=list(zip(
        FileNames,
        IntergenomicGC,
        AAA,
        ACA,
        AGA,
        TTA,
        TCA,
        CAA,
        CTA,
        CCA,
        CGA,
        GAA,
        GTA,
        GCA,
        GGA,
        AAT,
        ACT,
        AGT,
        TAT,
        TTT,
        TCT,
        TGT,
        CAT,
        CTT,
        CCT,
        CGT,
        GAT,
        GTT,
        GCT,
        GGT,
        AAC,
        ACC,
        AGC, 
        TAC,
        TTC,
        TCC,
        TGC,
        CAC,
        CTC,
        CCC,
        CGC,
        GAC,
        GTC,
        GCC,
        GGC,
        AAG,
        ACG,
        AGG,
        TTG,
        TCG,
        CAG,
        CTG,
        CCG,
        CGG,
        GAG,
        GTG,
        GCG,
        GGG)
    ),
    columns=[
        "Name",
        "IntergenicGC",
        "AAA",
        "ACA",
        "AGA",
        "TTA",
        "TCA",
        "CAA",
        "CTA",
        "CCA",
        "CGA",
        "GAA",
        "GTA",
        "GCA",
        "GGA",
        "AAT",
        "ACT",
        "AGT",
        "TAT",
        "TTT",
        "TCT",
        "TGT",
        "CAT",
        "CTT",
        "CCT",
        "CGT",
        "GAT",
        "GTT",
        "GCT",
        "GGT",
        "AAC",
        "ACC",
        "AGC", 
        "TAC",
        "TTC",
        "TCC",
        "TGC",
        "CAC",
        "CTC",
        "CCC",
        "CGC",
        "GAC",
        "GTC",
        "GCC",
        "GGC",
        "AAG",
        "ACG",
        "AGG",
        "TTG",
        "TCG",
        "CAG",
        "CTG",
        "CCG",
        "CGG",
        "GAG",
        "GTG",
        "GCG",
        "GGG"
    ],
    index=range(1, files_tot+1)
)

folder = "results/"
print(f"Saving data to the {folder} folder")
df.to_csv(f"{folder}data.csv", index=False)
# Out:
# Saving data to the results/ folder
