# %%
from Bio import SeqIO
from Bio.Seq import Seq
import pandas as pd
from os import walk
import os
mypath = os.path.abspath(os.getcwd()) + "/filtered_genomes"

files = []
for (dirpath, dirnames, filenames) in walk(mypath):
    files.extend(filenames)
    break

ext = "embl"

FileNames = []
IntergenomicGC = []
AAA = []
ACA = []
AGA = []
TTA = []
TCA = []
CAA = []
CTA = []
CCA = []
CGA = []
GAA = []
GTA = []
GCA = []
GGA = []
AAT = []
ACT = []
AGT = []
TAT = []
TTT = []
TCT = []
TGT = []
CAT = []
CTT = []
CCT = []
CGT = []
GAT = []
GTT = []
GCT = []
GGT = []
AAC = []
ACC = []
AGC = [] 
TAC = []
TTC = []
TCC = []
TGC = []
CAC = []
CTC = []
CCC = []
CGC = []
GAC = []
GTC = []
GCC = []
GGC = []
AAG = []
ACG = []
AGG = []
TTG = []
TCG = []
CAG = []
CTG = []
CCG = []
CGG = []
GAG = []
GTG = []
GCG = []
GGG = []


files_tot = len(files)
for index, name in enumerate(files):
    print("\n")
    print(f"Analyzing file {index+1} of {files_tot}: {name}")
    print("\n")
    record = SeqIO.read(f'filtered_genomes/{name}', ext)
    sequence = record.seq
    FileNames.append(str(name))
    
    start = 0
    coding_sequences = []
    intergenomic_sequence = []  # It will contain the sequences out of the locations bounds
    intergenomic_sequence_list = []  # It will contain the locations bounds
    intergenomic_sequence_string = ""  # intergenomic sequence
    
    for feature in record.features:

        locations= feature.location
        s = int(locations.nofuzzy_start)
        e = int(locations.nofuzzy_end)
        st = int(locations.strand)
        
        gene_start = int(locations.nofuzzy_start)

        if gene_start > start:
            ig_sequence = sequence[start:gene_start]
            intergenomic_sequence.append(str(ig_sequence))
            intergenomic_sequence_list.append((start, gene_start))

        new_start = int(locations.nofuzzy_end)

        if new_start != len(sequence):
            start = new_start

        #Reversing complementary strands
        if st == -1:
            sequence_negativestrand = str(sequence[s:e])
            sequence_negativestrand= sequence_negativestrand[::-1]
            sequence_negativestrand= sequence_negativestrand.replace("A","b")
            sequence_negativestrand= sequence_negativestrand.replace("T","A")
            sequence_negativestrand= sequence_negativestrand.replace("b","T")
            sequence_negativestrand= sequence_negativestrand.replace("C","d")
            sequence_negativestrand= sequence_negativestrand.replace("G","C")
            sequence_negativestrand= sequence_negativestrand.replace("d","G")

        #Discarding the pseudogenes

            ok = 0
            genes = str(sequence_negativestrand)


            if len(genes)%3 != 0:
                ok= 1
            elif genes[:3] != "ATG" and genes[:3] != "GTG" and genes[:3] != "TTG":
                ok= 2
            elif genes[-3:] != "TAA" and genes[-3:] != "TAG" and genes[-3:] != "TGA":
                ok= 3


            if st == -1 and ok == 0:
                coding_sequences.append(genes)
        
        ok = 0
        genes = str(sequence[s:e])
    
        if len(genes)%3 != 0:
            ok= 1
        elif genes[:3] != "ATG" and genes[:3] != "GTG" and genes[:3] != "TTG":
            ok= 2
        elif genes[-3:] != "TAA" and genes[-3:] != "TAG" and genes[-3:] != "TGA":
            ok= 3
        elif len(genes) == len(sequence):
            ok= 4

        if st == 1 and ok == 0:
            coding_sequences.append(genes)

        #checking for errors
        check = False
        if check and st == 1 and ok != 0:
            print(locations)
            print(ok)
            print(genes[:3])
            print(genes[-3:])
            
    if start != len(sequence):
        ig_sequence = sequence[start:len(sequence)]
        intergenomic_sequence.append(str(ig_sequence))
        intergenomic_sequence_list.append((start, gene_start))

    intergenomic_sequence_string = "".join(intergenomic_sequence)

    # Intergenomic GC content
    IgGC = intergenomic_sequence_string.count("G") + intergenomic_sequence_string.count("C")
    IgGC_content = (IgGC / len(intergenomic_sequence_string)) * 100
    print(f"Intergenomic GC content: {IgGC_content:.2f}%")
    IntergenomicGC.append(IgGC_content)
    
    coding_sequencewhole = "".join(coding_sequences)
    aminoacids_sequence = Seq(coding_sequencewhole).translate()
    
    
    #Codon counting 
    AAAcount = 0
    AATcount = 0
    AACcount = 0
    AAGcount = 0
    ACAcount = 0
    ACCcount = 0
    ACGcount = 0
    ACTcount = 0
    AGAcount = 0
    AGTcount = 0
    AGCcount = 0
    AGGcount = 0
    TATcount = 0
    TACcount = 0
    TTAcount = 0
    TTTcount = 0
    TTCcount = 0
    TTGcount = 0
    TCAcount = 0
    TCCcount = 0
    TCGcount = 0
    TCTcount = 0
    TGTcount = 0
    TGCcount = 0
    CAAcount = 0  
    CATcount = 0
    CACcount = 0
    CAGcount = 0
    CTAcount = 0
    CTCcount = 0
    CTGcount = 0
    CTTcount = 0
    CCAcount = 0
    CCCcount = 0
    CCGcount = 0
    CCTcount = 0
    CGAcount = 0
    CGCcount = 0
    CGGcount = 0
    CGTcount = 0
    GAAcount = 0
    GATcount = 0
    GACcount = 0
    GAGcount = 0
    GTAcount = 0
    GTCcount = 0
    GTGcount = 0
    GTTcount = 0
    GCAcount = 0
    GCCcount = 0
    GCGcount = 0
    GCTcount = 0
    GGTcount = 0
    GGCcount = 0
    GGAcount = 0
    GGGcount = 0
    
    for cds in coding_sequences:
        for i in range(0, len(cds), 3):
            codons = cds[i: i + 3]
            AAA1 = codons.count("AAA")
            AAAcount += AAA1
            AAT1 = codons.count("AAT")
            AATcount += AAT1
            AAC1 = codons.count("AAC")
            AACcount += AAC1
            AAG1 = codons.count("AAG")
            AAGcount += AAG1
            ACA1 = codons.count("ACA")
            ACAcount += ACA1
            ACC1 = codons.count("ACC")
            ACCcount += ACC1
            ACG1 = codons.count("ACG")
            ACGcount += ACG1
            ACT1 = codons.count("ACT")
            ACTcount += ACT1
            AGA1 = codons.count("AGA")
            AGAcount += AGA1
            AGT1 = codons.count("AGT")
            AGTcount += AGT1
            AGC1 = codons.count("AGC")
            AGCcount += AGC1
            AGG1 = codons.count("AGG")
            AGGcount += AGG1
            CAA1 = codons.count("CAA")
            CAAcount += CAA1
            CAT1 = codons.count("CAT")
            CATcount += CAT1
            CAC1 = codons.count("CAC")
            CACcount += CAC1
            CAG1 = codons.count("CAG")
            CAGcount += CAG1
            CCA1 = codons.count("CCA")
            CCAcount += CCA1
            CCC1 = codons.count("CCC")
            CCCcount += CCC1
            CCG1 = codons.count("CCG")
            CCGcount += CCG1
            CCT1 = codons.count("CCT")
            CCTcount += CCT1
            CTA1 = codons.count("CTA")
            CTAcount += CTA1
            CTC1 = codons.count("CTC")
            CTCcount += CTC1
            CTG1 = codons.count("CTG")
            CTGcount += CTG1
            CTT1 = codons.count("CTT")
            CTTcount += CTT1
            CGA1 = codons.count("CGA")
            CGAcount += CGA1
            CGC1 = codons.count("CGC")
            CGCcount += CGC1
            CGG1 = codons.count("CGG")
            CGGcount += CGG1
            CGT1 = codons.count("CGT")
            CGTcount += CGT1
            TAT1 = codons.count("TAT")
            TATcount += TAT1
            TAC1 = codons.count("TAC")
            TACcount += TAC1
            TCA1 = codons.count("TCA")
            TCAcount += TCA1
            TCC1 = codons.count("TCC")
            TCCcount += TCC1
            TCG1 = codons.count("TCG")
            TCGcount += TCG1
            TCT1 = codons.count("TCT")
            TCTcount += TCT1
            TTA1 = codons.count("TTA")
            TTAcount += TTA1
            TTT1 = codons.count("TTT")
            TTTcount += TTT1
            TTC1 = codons.count("TTC")
            TTCcount += TTC1
            TTG1 = codons.count("TTG")
            TTGcount += TTG1
            TGT1 = codons.count("TGT")
            TGTcount += TGT1
            TGC1 = codons.count("TGC")
            TGCcount += TGC1
            GAA1 = codons.count("GAA")
            GAAcount += GAA1
            GAT1 = codons.count("GAT")
            GATcount += GAT1
            GAC1 = codons.count("GAC")
            GACcount += GAC1
            GAG1 = codons.count("GAG")
            GAGcount += GAG1
            GTA1 = codons.count("GTA")
            GTAcount += GTA1
            GTC1 = codons.count("GTC")
            GTCcount += GTC1
            GTG1 = codons.count("GTG")
            GTGcount += GTG1
            GTT1 = codons.count("GTT")
            GTTcount += GTT1
            GCA1 = codons.count("GCA")
            GCAcount += GCA1
            GCC1 = codons.count("GCC")
            GCCcount += GCC1
            GCG1 = codons.count("GCG")
            GCGcount += GCG1
            GCT1 = codons.count("GCT")
            GCTcount += GCT1
            GGA1 = codons.count("GGA")
            GGAcount += GGA1
            GGC1 = codons.count("GGC")
            GGCcount += GGC1
            GGG1 = codons.count("GGG")
            GGGcount += GGG1
            GGT1 = codons.count("GGT")
            GGTcount += GGT1
            
    
    
    AAA.append(AAAcount/ (AAAcount+AAGcount)*100)
    AAT.append(AATcount/ (AATcount+AACcount)*100)
    AAC.append(AACcount/ (AATcount+AACcount)*100)
    AAG.append(AAGcount/ (AAAcount+AAGcount)*100)
    ACA.append(ACAcount/ (ACAcount+ACTcount+ACCcount+ACGcount)*100)
    ACC.append(ACCcount/ (ACAcount+ACTcount+ACCcount+ACGcount)*100)
    ACG.append(ACGcount/ (ACAcount+ACTcount+ACCcount+ACGcount)*100)
    ACT.append(ACTcount/ (ACAcount+ACTcount+ACCcount+ACGcount)*100)
    AGA.append(AGAcount/ (AGAcount+AGGcount)*100)
    AGT.append(AGTcount/ (AGTcount+AGCcount)*100)
    AGC.append(AGCcount/ (AGTcount+AGCcount)*100)
    AGG.append(AGGcount/ (AGAcount+AGGcount)*100)
    TAT.append(TATcount/ (TATcount+TACcount)*100)
    TAC.append(TACcount/ (TATcount+TACcount)*100)
    TTA.append(TTAcount/ (TTAcount+TTGcount)*100)
    TTT.append(TTTcount/ (TTTcount+TTCcount)*100)
    TTC.append(TTCcount/ (TTTcount+TTCcount)*100)
    TTG.append(TTGcount/ (TTAcount+TTGcount)*100)
    TCA.append(TCAcount/ (TCAcount+TCTcount+TCGcount+TCCcount)*100)
    TCC.append(TCCcount/ (TCAcount+TCTcount+TCGcount+TCCcount)*100)
    TCG.append(TCGcount/ (TCAcount+TCTcount+TCGcount+TCCcount)*100)
    TCT.append(TCTcount/ (TCAcount+TCTcount+TCGcount+TCCcount)*100)
    TGT.append(TGTcount/ (TGTcount+TGCcount)*100)
    TGC.append(TGCcount/ (TGTcount+TGCcount)*100)
    CAA.append(CAAcount/ (CAAcount+CAGcount)*100)
    CAT.append(CATcount/ (CACcount+CATcount)*100)
    CAC.append(CACcount/ (CACcount+CATcount)*100)
    CAG.append(CAGcount/ (CAAcount+CAGcount)*100)
    CTA.append(CTAcount/ (CTAcount+CTCcount+CTCcount+CTTcount)*100)
    CTC.append(CTCcount/ (CTAcount+CTCcount+CTCcount+CTTcount)*100)
    CTG.append(CTGcount/ (CTAcount+CTCcount+CTCcount+CTTcount)*100)
    CTT.append(CTTcount/ (CTAcount+CTCcount+CTCcount+CTTcount)*100)
    CCA.append(CCAcount/ (CCAcount+CCTcount+CCCcount+CCGcount)*100)
    CCC.append(CCCcount/ (CCAcount+CCTcount+CCCcount+CCGcount)*100)
    CCG.append(CCGcount/ (CCAcount+CCTcount+CCCcount+CCGcount)*100)
    CCT.append(CCTcount/ (CCAcount+CCTcount+CCCcount+CCGcount)*100)
    CGA.append(CGAcount/ (CGAcount+CGTcount+CGCcount+CGGcount)*100)
    CGC.append(CGCcount/ (CGAcount+CGTcount+CGCcount+CGGcount)*100)
    CGG.append(CGGcount/ (CGAcount+CGTcount+CGCcount+CGGcount)*100)
    CGT.append(CGTcount/ (CGAcount+CGTcount+CGCcount+CGGcount)*100)
    GAA.append(GAAcount/ (GAAcount+GAGcount)*100)
    GAT.append(GATcount/ (GACcount+GATcount)*100)
    GAC.append(GACcount/ (GACcount+GATcount)*100)
    GAG.append(GAGcount/ (GAAcount+GAGcount)*100)
    GTA.append(GTAcount/ (GTAcount+GTTcount+GTCcount+GTGcount)*100)
    GTC.append(GTCcount/ (GTAcount+GTTcount+GTCcount+GTGcount)*100)
    GTG.append(GTGcount/ (GTAcount+GTTcount+GTCcount+GTGcount)*100)
    GTT.append(GTTcount/ (GTAcount+GTTcount+GTCcount+GTGcount)*100)
    GCA.append(GCAcount/ (GCAcount+GCTcount+GCCcount+GCGcount)*100)
    GCC.append(GCCcount/ (GCAcount+GCTcount+GCCcount+GCGcount)*100)
    GCG.append(GCGcount/ (GCAcount+GCTcount+GCCcount+GCGcount)*100)
    GCT.append(GCTcount/ (GCAcount+GCTcount+GCCcount+GCGcount)*100)
    GGT.append(GGTcount/ (GGAcount+GGTcount+GGCcount+GGGcount)*100)
    GGA.append(GGAcount/ (GGAcount+GGTcount+GGCcount+GGGcount)*100)
    GGG.append(GGGcount/ (GGAcount+GGTcount+GGCcount+GGGcount)*100)
    GGC.append(GGCcount/ (GGAcount+GGTcount+GGCcount+GGGcount)*100)
# Out:
# Analyzing file 1 of 200: CP003532.embl
#
#
# Intergenomic GC content: 44.79%
#
#
# Analyzing file 2 of 200: CP003546.embl
#
#
# Intergenomic GC content: 39.04%
#
#
# Analyzing file 3 of 200: CP003549.embl
#
#
# Intergenomic GC content: 34.14%
#
#
# Analyzing file 4 of 200: CP003557.embl
#
#
# Intergenomic GC content: 33.40%
#
#
# Analyzing file 5 of 200: CP003558.embl
#
#
# Intergenomic GC content: 45.15%
#
#
# Analyzing file 6 of 200: CP003563.embl
#
#
# Intergenomic GC content: 57.80%
#
#
# Analyzing file 7 of 200: CP003587.embl
#
#
# Intergenomic GC content: 52.34%
#
#
# Analyzing file 8 of 200: CP003590.embl
#
#
# Intergenomic GC content: 40.27%
#
#
# Analyzing file 9 of 200: CP003591.embl
#
#
# Intergenomic GC content: 53.73%
#
#
# Analyzing file 10 of 200: CP003592.embl
#
#
# Intergenomic GC content: 39.92%
#
#
# Analyzing file 11 of 200: CP003597.embl
#
#
# Intergenomic GC content: 41.34%
#
#
# Analyzing file 12 of 200: CP003600.embl
#
#
# Intergenomic GC content: 42.80%
#
#
# Analyzing file 13 of 200: CP003607.embl
#
#
# Intergenomic GC content: 46.12%
#
#
# Analyzing file 14 of 200: CP003620.embl
#
#
# Intergenomic GC content: 36.74%
#
#
# Analyzing file 15 of 200: CP003630.embl
#
#
# Intergenomic GC content: 43.94%
#
#
# Analyzing file 16 of 200: CP003642.embl
#
#
# Intergenomic GC content: 38.86%
#
#
# Analyzing file 17 of 200: CP003646.embl
#
#
# Intergenomic GC content: 39.31%
#
#
# Analyzing file 18 of 200: CP003653.embl
#
#
# Intergenomic GC content: 31.91%
#
#
# Analyzing file 19 of 200: CP003659.embl
#
#
# Intergenomic GC content: 36.12%
#
#
# Analyzing file 20 of 200: CP003729.embl
#
#
# Intergenomic GC content: 67.05%
#
#
# Analyzing file 21 of 200: CP003732.embl
#
#
# Intergenomic GC content: 48.59%
#
#
# Analyzing file 22 of 200: CP003742.embl
#
#
# Intergenomic GC content: 51.15%
#
#
# Analyzing file 23 of 200: CP003746.embl
#
#
# Intergenomic GC content: 50.22%
#
#
# Analyzing file 24 of 200: CP003778.embl
#
#
# Intergenomic GC content: 62.63%
#
#
# Analyzing file 25 of 200: CP003787.embl
#
#
# Intergenomic GC content: 27.79%
#
#
# Analyzing file 26 of 200: CP003788.embl
#
#
# Intergenomic GC content: 66.65%
#
#
# Analyzing file 27 of 200: CP003789.embl
#
#
# Intergenomic GC content: 26.82%
#
#
# Analyzing file 28 of 200: CP003796.embl
#
#
# Intergenomic GC content: 32.67%
#
#
# Analyzing file 29 of 200: CP003801.embl
#
#
# Intergenomic GC content: 31.07%
#
#
# Analyzing file 30 of 200: CP003837.embl
#
#
# Intergenomic GC content: 35.30%
#
#
# Analyzing file 31 of 200: CP003870.embl
#
#
# Intergenomic GC content: 36.72%
#
#
# Analyzing file 32 of 200: CP003876.embl
#
#
# Intergenomic GC content: 63.99%
#
#
# Analyzing file 33 of 200: CP003879.embl
#
#
# Intergenomic GC content: 30.05%
#
#
# Analyzing file 34 of 200: CP003915.embl
#
#
# Intergenomic GC content: 47.59%
#
#
# Analyzing file 35 of 200: CP003926.embl
#
#
# Intergenomic GC content: 49.57%
#
#
# Analyzing file 36 of 200: CP003943.embl
#
#
# Intergenomic GC content: 39.57%
#
#
# Analyzing file 37 of 200: CP003944.embl
#
#
# Intergenomic GC content: 40.72%
#
#
# Analyzing file 38 of 200: CP003945.embl
#
#
# Intergenomic GC content: 40.34%
#
#
# Analyzing file 39 of 200: CP003946.embl
#
#
# Intergenomic GC content: 40.14%
#
#
# Analyzing file 40 of 200: CP003947.embl
#
#
# Intergenomic GC content: 32.12%
#
#
# Analyzing file 41 of 200: CP003949.embl
#
#
# Intergenomic GC content: 62.56%
#
#
# Analyzing file 42 of 200: CP003969.embl
#
#
# Intergenomic GC content: 72.05%
#
#
# Analyzing file 43 of 200: CP003984.embl
#
#
# Intergenomic GC content: 47.85%
#
#
# Analyzing file 44 of 200: CP003985.embl
#
#
# Intergenomic GC content: 42.63%
#
#
# Analyzing file 45 of 200: CP003989.embl
#
#
# Intergenomic GC content: 64.63%
#
#
# Analyzing file 46 of 200: CP004025.embl
#
#
# Intergenomic GC content: 66.75%
#
#
# Analyzing file 47 of 200: CP004083.embl
#
#
# Intergenomic GC content: 40.74%
#
#
# Analyzing file 48 of 200: CP004121.embl
#
#
# Intergenomic GC content: 24.55%
#
#
# Analyzing file 49 of 200: CP004345.embl
#
#
# Intergenomic GC content: 40.32%
#
#
# Analyzing file 50 of 200: CP004348.embl
#
#
# Intergenomic GC content: 38.95%
#
#
# Analyzing file 51 of 200: CP004349.embl
#
#
# Intergenomic GC content: 23.36%
#
#
# Analyzing file 52 of 200: CP004372.embl
#
#
# Intergenomic GC content: 63.53%
#
#
# Analyzing file 53 of 200: CP004388.embl
#
#
# Intergenomic GC content: 49.33%
#
#
# Analyzing file 54 of 200: CP004393.embl
#
#
# Intergenomic GC content: 62.26%
#
#
# Analyzing file 55 of 200: CP004856.embl
#
#
# Intergenomic GC content: 35.69%
#
#
# Analyzing file 56 of 200: CP005094.embl
#
#
# Intergenomic GC content: 60.71%
#
#
# Analyzing file 57 of 200: CP005383.embl
#
#
# Intergenomic GC content: 32.76%
#
#
# Analyzing file 58 of 200: CP005384.embl
#
#
# Intergenomic GC content: 32.51%
#
#
# Analyzing file 59 of 200: CP005964.embl
#
#
# Intergenomic GC content: 40.24%
#
#
# Analyzing file 60 of 200: CP005990.embl
#
#
# Intergenomic GC content: 57.81%
#
#
# Analyzing file 61 of 200: CP005996.embl
#
#
# Intergenomic GC content: 35.52%
#
#
# Analyzing file 62 of 200: CP006265.embl
#
#
# Intergenomic GC content: 32.73%
#
#
# Analyzing file 63 of 200: CP006272.embl
#
#
# Intergenomic GC content: 65.97%
#
#
# Analyzing file 64 of 200: CP006566.embl
#
#
# Intergenomic GC content: 46.45%
#
#
# Analyzing file 65 of 200: CP006569.embl
#
#
# Intergenomic GC content: 53.39%
#
#
# Analyzing file 66 of 200: CP006587.embl
#
#
# Intergenomic GC content: 53.73%
#
#
# Analyzing file 67 of 200: CP006597.embl
#
#
# Intergenomic GC content: 32.29%
#
#
# Analyzing file 68 of 200: CP006617.embl
#
#
# Intergenomic GC content: 38.79%
#
#
# Analyzing file 69 of 200: CP006644.embl
#
#
# Intergenomic GC content: 62.21%
#
#
# Analyzing file 70 of 200: CP006650.embl
#
#
# Intergenomic GC content: 58.98%
#
#
# Analyzing file 71 of 200: CP006664.embl
#
#
# Intergenomic GC content: 51.89%
#
#
# Analyzing file 72 of 200: CP006696.embl
#
#
# Intergenomic GC content: 45.11%
#
#
# Analyzing file 73 of 200: CP006704.embl
#
#
# Intergenomic GC content: 54.87%
#
#
# Analyzing file 74 of 200: CP006734.embl
#
#
# Intergenomic GC content: 65.77%
#
#
# Analyzing file 75 of 200: CP006772.embl
#
#
# Intergenomic GC content: 32.84%
#
#
# Analyzing file 76 of 200: CP006773.embl
#
#
# Intergenomic GC content: 58.81%
#
#
# Analyzing file 77 of 200: CP006842.embl
#
#
# Intergenomic GC content: 60.10%
#
#
# Analyzing file 78 of 200: CP006866.embl
#
#
# Intergenomic GC content: 38.98%
#
#
# Analyzing file 79 of 200: CP006914.embl
#
#
# Intergenomic GC content: 38.89%
#
#
# Analyzing file 80 of 200: CP006939.embl
#
#
# Intergenomic GC content: 47.04%
#
#
# Analyzing file 81 of 200: CP006949.embl
#
#
# Intergenomic GC content: 38.23%
#
#
# Analyzing file 82 of 200: CP006955.embl
#
#
# Intergenomic GC content: 34.27%
#
#
# Analyzing file 83 of 200: CP006958.embl
#
#
# Intergenomic GC content: 61.82%
#
#
# Analyzing file 84 of 200: CP007028.embl
#
#
# Intergenomic GC content: 38.12%
#
#
# Analyzing file 85 of 200: CP007030.embl
#
#
# Intergenomic GC content: 38.06%
#
#
# Analyzing file 86 of 200: CP007031.embl
#
#
# Intergenomic GC content: 63.52%
#
#
# Analyzing file 87 of 200: CP007034.embl
#
#
# Intergenomic GC content: 40.26%
#
#
# Analyzing file 88 of 200: CP007035.embl
#
#
# Intergenomic GC content: 38.42%
#
#
# Analyzing file 89 of 200: CP007044.embl
#
#
# Intergenomic GC content: 42.59%
#
#
# Analyzing file 90 of 200: CP007051.embl
#
#
# Intergenomic GC content: 27.49%
#
#
# Analyzing file 91 of 200: CP007053.embl
#
#
# Intergenomic GC content: 56.41%
#
#
# Analyzing file 92 of 200: CP007062.embl
#
#
# Intergenomic GC content: 22.40%
#
#
# Analyzing file 93 of 200: CP007128.embl
#
#
# Intergenomic GC content: 69.58%
#
#
# Analyzing file 94 of 200: CP007139.embl
#
#
# Intergenomic GC content: 57.05%
#
#
# Analyzing file 95 of 200: CP007142.embl
#
#
# Intergenomic GC content: 41.97%
#
#
# Analyzing file 96 of 200: CP007152.embl
#
#
# Intergenomic GC content: 51.01%
#
#
# Analyzing file 97 of 200: CP007155.embl
#
#
# Intergenomic GC content: 65.98%
#
#
# Analyzing file 98 of 200: CP007161.embl
#
#
# Intergenomic GC content: 34.28%
#
#
# Analyzing file 99 of 200: CP007201.embl
#
#
# Intergenomic GC content: 32.61%
#
#
# Analyzing file 100 of 200: CP007202.embl
#
#
# Intergenomic GC content: 24.81%
#
#
# Analyzing file 101 of 200: CP007444.embl
#
#
# Intergenomic GC content: 61.52%
#
#
# Analyzing file 102 of 200: CP007445.embl
#
#
# Intergenomic GC content: 25.78%
#
#
# Analyzing file 103 of 200: CP007446.embl
#
#
# Intergenomic GC content: 29.72%
#
#
# Analyzing file 104 of 200: CP007447.embl
#
#
# Intergenomic GC content: 27.99%
#
#
# Analyzing file 105 of 200: CP007451.embl
#
#
# Intergenomic GC content: 34.51%
#
#
# Analyzing file 106 of 200: CP007481.embl
#
#
# Intergenomic GC content: 38.65%
#
#
# Analyzing file 107 of 200: CP007519.embl
#
#
# Intergenomic GC content: 53.40%
#
#
# Analyzing file 108 of 200: CP007566.embl
#
#
# Intergenomic GC content: 50.03%
# Analyzing file 109 of 200: CP008788.embl
#
#
# Intergenomic GC content: 46.64%
#
#
# Analyzing file 110 of 200: CP008796.embl
#
#
# Intergenomic GC content: 34.64%
#
#
# Analyzing file 111 of 200: CP008802.embl
#
#
# Intergenomic GC content: 61.27%
#
#
# Analyzing file 112 of 200: CP008803.embl
#
#
# Intergenomic GC content: 56.22%
#
#
# Analyzing file 113 of 200: CP008804.embl
#
#
# Intergenomic GC content: 31.74%
#
#
# Analyzing file 114 of 200: CP008876.embl
#
#
# Intergenomic GC content: 39.00%
#
#
# Analyzing file 115 of 200: CP008889.embl
#
#
# Intergenomic GC content: 69.06%
#
#
# Analyzing file 116 of 200: CP009056.embl
#
#
# Intergenomic GC content: 25.63%
#
#
# Analyzing file 117 of 200: CP009122.embl
#
#
# Intergenomic GC content: 59.09%
#
#
# Analyzing file 118 of 200: CP009129.embl
#
#
# Intergenomic GC content: 34.61%
#
#
# Analyzing file 119 of 200: CP009159.embl
#
#
# Intergenomic GC content: 31.80%
#
#
# Analyzing file 120 of 200: CP009217.embl
#
#
# Intergenomic GC content: 25.14%
#
#
# Analyzing file 121 of 200: CP009257.embl
#
#
# Intergenomic GC content: 31.63%
#
#
# Analyzing file 122 of 200: CP009291.embl
#
#
# Intergenomic GC content: 60.11%
#
#
# Analyzing file 123 of 200: CP009301.embl
#
#
# Intergenomic GC content: 31.50%
#
#
# Analyzing file 124 of 200: CP009302.embl
#
#
# Intergenomic GC content: 61.87%
#
#
# Analyzing file 125 of 200: CP009415.embl
#
#
# Intergenomic GC content: 26.76%
#
#
# Analyzing file 126 of 200: CP009416.embl
#
#
# Intergenomic GC content: 38.79%
#
#
# Analyzing file 127 of 200: CP009440.embl
#
#
# Intergenomic GC content: 23.74%
#
#
# Analyzing file 128 of 200: CP009450.embl
#
#
# Intergenomic GC content: 47.00%
#
#
# Analyzing file 129 of 200: CP009460.embl
#
#
# Intergenomic GC content: 49.40%
#
#
# Analyzing file 130 of 200: CP009495.embl
#
#
# Intergenomic GC content: 61.54%
#
#
# Analyzing file 131 of 200: CP009621.embl
#
#
# Intergenomic GC content: 40.49%
#
#
# Analyzing file 132 of 200: CP009706.embl
#
#
# Intergenomic GC content: 40.95%
#
#
# Analyzing file 133 of 200: CP009761.embl
#
#
# Intergenomic GC content: 24.37%
#
#
# Analyzing file 134 of 200: CP009962.embl
#
#
# Intergenomic GC content: 47.36%
#
#
# Analyzing file 135 of 200: CP010049.embl
#
#
# Intergenomic GC content: 17.40%
#
#
# Analyzing file 136 of 200: CP010310.embl
#
#
# Intergenomic GC content: 60.47%
#
#
# Analyzing file 137 of 200: CP010311.embl
#
#
# Intergenomic GC content: 50.53%
#
#
# Analyzing file 138 of 200: CP010327.embl
#
#
# Intergenomic GC content: 27.37%
#
#
# Analyzing file 139 of 200: CP010557.embl
#
#
# Intergenomic GC content: 47.63%
#
#
# Analyzing file 140 of 200: CP010803.embl
#
#
# Intergenomic GC content: 56.71%
#
#
# Analyzing file 141 of 200: CP010812.embl
#
#
# Intergenomic GC content: 41.31%
#
#
# Analyzing file 142 of 200: CP010820.embl
#
#
# Intergenomic GC content: 32.77%
#
#
# Analyzing file 143 of 200: CP010848.embl
#
#
# Intergenomic GC content: 58.96%
#
#
# Analyzing file 144 of 200: CP010954.embl
#
#
# Intergenomic GC content: 59.39%
#
#
# Analyzing file 145 of 200: CP010978.embl
#
#
# Intergenomic GC content: 35.13%
#
#
# Analyzing file 146 of 200: CP011047.embl
#
#
# Intergenomic GC content: 47.75%
#
#
# Analyzing file 147 of 200: CP011052.embl
#
#
# Intergenomic GC content: 49.20%
#
#
# Analyzing file 148 of 200: CP011132.embl
#
#
# Intergenomic GC content: 44.41%
#
#
# Analyzing file 149 of 200: CP011144.embl
#
#
# Intergenomic GC content: 67.58%
#
#
# Analyzing file 150 of 200: CP011265.embl
#
#
# Intergenomic GC content: 57.01%
#
#
# Analyzing file 151 of 200: CP011280.embl
#
#
# Intergenomic GC content: 25.16%
#
#
# Analyzing file 152 of 200: CP011301.embl
#
#
# Intergenomic GC content: 63.47%
#
#
# Analyzing file 153 of 200: CR522870.embl
#
#
# Intergenomic GC content: 40.99%
#
#
# Analyzing file 154 of 200: CR767821.embl
#
#
# Intergenomic GC content: 25.02%
#
#
# Analyzing file 155 of 200: CU207211.embl
#
#
# Intergenomic GC content: 46.67%
#
#
# Analyzing file 156 of 200: CU207366.embl
#
#
# Intergenomic GC content: 29.39%
#
#
# Analyzing file 157 of 200: FM162591.embl
#
#
# Intergenomic GC content: 38.62%
#
#
# Analyzing file 158 of 200: FM178379.embl
#
#
# Intergenomic GC content: 37.49%
#
#
# Analyzing file 159 of 200: FO082060.embl
#
#
# Intergenomic GC content: 44.72%
#
#
# Analyzing file 160 of 200: FO117623.embl
#
#
# Intergenomic GC content: 72.30%
#
#
# Analyzing file 161 of 200: FO203355.embl
#
#
# Intergenomic GC content: 45.84%
#
#
# Analyzing file 162 of 200: FO203431.embl
#
#
# Intergenomic GC content: 73.45%
#
#
# Analyzing file 163 of 200: FO203503.embl
#
#
# Intergenomic GC content: 35.04%
#
#
# Analyzing file 164 of 200: FO538765.embl
#
#
# Intergenomic GC content: 53.06%
#
#
# Analyzing file 165 of 200: FO818637.embl
#
#
# Intergenomic GC content: 35.10%
#
#
# Analyzing file 166 of 200: FP236843.embl
#
#
# Intergenomic GC content: 46.65%
#
#
# Analyzing file 167 of 200: FP475956.embl
#
#
# Intergenomic GC content: 57.74%
#
#
# Analyzing file 168 of 200: FP476056.embl
#
#
# Intergenomic GC content: 34.61%
#
#
# Analyzing file 169 of 200: FP565814.embl
#
#
# Intergenomic GC content: 61.95%
#
#
# Analyzing file 170 of 200: FP929032.embl
#
#
# Intergenomic GC content: 54.11%
#
#
# Analyzing file 171 of 200: FP929038.embl
#
#
# Intergenomic GC content: 39.83%
#
#
# Analyzing file 172 of 200: FP929045.embl
#
#
# Intergenomic GC content: 51.91%
#
#
# Analyzing file 173 of 200: FP929047.embl
#
#
# Intergenomic GC content: 65.81%
#
#
# Analyzing file 174 of 200: FP929048.embl
#
#
# Intergenomic GC content: 29.48%
#
#
# Analyzing file 175 of 200: FP929050.embl
#
#
# Intergenomic GC content: 39.62%
#
#
# Analyzing file 176 of 200: FP929054.embl
#
#
# Intergenomic GC content: 39.86%
#
#
# Analyzing file 177 of 200: FP929056.embl
#
#
# Intergenomic GC content: 62.25%
#
#
# Analyzing file 178 of 200: FP929061.embl
#
#
# Intergenomic GC content: 34.18%
#
#
# Analyzing file 179 of 200: FP929062.embl
#
#
# Intergenomic GC content: 44.61%
#
#
# Analyzing file 180 of 200: FQ312005.embl
#
#
# Intergenomic GC content: 36.15%
#
#
# Analyzing file 181 of 200: FQ859181.embl
#
#
# Intergenomic GC content: 55.59%
#
#
# Analyzing file 182 of 200: FR872580.embl
#
#
# Intergenomic GC content: 32.14%
#
#
# Analyzing file 183 of 200: FR872582.embl
#
#
# Intergenomic GC content: 34.09%
#
#
# Analyzing file 184 of 200: HE717023.embl
#
#
# Intergenomic GC content: 35.85%
#
#
# Analyzing file 185 of 200: HE804045.embl
#
#
# Intergenomic GC content: 69.48%
#
#
# Analyzing file 186 of 200: HE956757.embl
#
#
# Intergenomic GC content: 60.03%
#
#
# Analyzing file 187 of 200: HE983995.embl
#
#
# Intergenomic GC content: 29.61%
#
#
# Analyzing file 188 of 200: HE999757.embl
#
#
# Intergenomic GC content: 29.69%
#
#
# Analyzing file 189 of 200: HF563609.embl
#
#
# Intergenomic GC content: 31.28%
#
#
# Analyzing file 190 of 200: HF571988.embl
#
#
# Intergenomic GC content: 40.59%
#
#
# Analyzing file 191 of 200: HF680312.embl
#
#
# Intergenomic GC content: 43.86%
#
#
# Analyzing file 192 of 200: HF951689.embl
#
#
# Intergenomic GC content: 48.35%
#
#
# Analyzing file 193 of 200: HG315671.embl
#
#
# Intergenomic GC content: 26.32%
#
#
# Analyzing file 194 of 200: HG322949.embl
#
#
# Intergenomic GC content: 51.44%
#
#
# Analyzing file 195 of 200: HG530068.embl
#
#
# Intergenomic GC content: 61.90%
#
#
# Analyzing file 196 of 200: HG934468.embl
#
#
# Intergenomic GC content: 39.78%
#
#
# Analyzing file 197 of 200: HG938353.embl
#
#
# Intergenomic GC content: 54.86%
#
#
# Analyzing file 198 of 200: LK028559.embl
#
#
# Intergenomic GC content: 27.48%
#
#
# Analyzing file 199 of 200: LN614827.embl
#
#
# Intergenomic GC content: 35.37%
#
#
# Analyzing file 200 of 200: LN614830.embl
#
#
# Intergenomic GC content: 35.87%

# %%
df = pd.DataFrame(
    data=list(zip(
        FileNames,
        IntergenomicGC,
        AAA,
        ACA,
        AGA,
        TTA,
        TCA,
        CAA,
        CTA,
        CCA,
        CGA,
        GAA,
        GTA,
        GCA,
        GGA,
        AAT,
        ACT,
        AGT,
        TAT,
        TTT,
        TCT,
        TGT,
        CAT,
        CTT,
        CCT,
        CGT,
        GAT,
        GTT,
        GCT,
        GGT,
        AAC,
        ACC,
        AGC, 
        TAC,
        TTC,
        TCC,
        TGC,
        CAC,
        CTC,
        CCC,
        CGC,
        GAC,
        GTC,
        GCC,
        GGC,
        AAG,
        ACG,
        AGG,
        TTG,
        TCG,
        CAG,
        CTG,
        CCG,
        CGG,
        GAG,
        GTG,
        GCG,
        GGG)
    ),
    columns=[
        "Name",
        "IntergenicGC",
        "AAA",
        "ACA",
        "AGA",
        "TTA",
        "TCA",
        "CAA",
        "CTA",
        "CCA",
        "CGA",
        "GAA",
        "GTA",
        "GCA",
        "GGA",
        "AAT",
        "ACT",
        "AGT",
        "TAT",
        "TTT",
        "TCT",
        "TGT",
        "CAT",
        "CTT",
        "CCT",
        "CGT",
        "GAT",
        "GTT",
        "GCT",
        "GGT",
        "AAC",
        "ACC",
        "AGC", 
        "TAC",
        "TTC",
        "TCC",
        "TGC",
        "CAC",
        "CTC",
        "CCC",
        "CGC",
        "GAC",
        "GTC",
        "GCC",
        "GGC",
        "AAG",
        "ACG",
        "AGG",
        "TTG",
        "TCG",
        "CAG",
        "CTG",
        "CCG",
        "CGG",
        "GAG",
        "GTG",
        "GCG",
        "GGG"
    ],
    index=range(1, files_tot+1)
)

folder = "results/"
print(f"Saving data to the {folder} folder")
df.to_csv(f"{folder}data.csv", index=False)
# Out:
# Saving data to the results/ folder
